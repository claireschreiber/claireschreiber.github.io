# %%
#Here we have Bing News Search, Sentiment Analysis, and requests and json()!

# %%
import requests

url = "https://microsoft-azure-bing-news-search-v1.p.rapidapi.com/"

headers = {
    'x-rapidapi-host': "microsoft-azure-bing-news-search-v1.p.rapidapi.com",
    'x-rapidapi-key': "56e59c14d3msh07e7b4221df836fp1fe2d5jsn225bea4577d6"
    }

response = requests.get(url, headers=headers)
response.json()
# Out:
# {'_type': 'News',
#  'webSearchUrl': 'https://www.bing.com/news/search?q=top+stories&form=TNSA02',
#  'value': [{'name': "Brazil's Bolsonaro Joins Supporters In Protest Against Coronavirus Measures",
#    'url': 'https://www.npr.org/sections/coronavirus-live-updates/2020/04/20/839233251/brazils-bolsonaro-joins-supporters-in-protest-against-coronavirus-measures',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.45CEE39FCA4ED485B1B9B157F06F65ED&pid=News',
#      'width': 700,
#      'height': 393}},
#    'description': "Brazil's far-right President Jair Bolsonaro is the focus of a fresh outcry after taking part in a public protest against democratic institutions that included calls for a military takeover. The president's participation in the event has caused outrage among judges, human rights groups, lawyers and others, and comes amid growing controversy over ...",
#    'about': [{'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/a828cf41-b938-49fe-7986-4b336618d413',
#      'name': 'Brazil'},
#     {'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/af660955-a30a-65d7-4c4e-89b41945bb5d',
#      'name': 'NPR'},
#     {'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/23e9096c-b560-ce3f-c9e1-846b117f0c87',
#      'name': 'Protest'}],
#    'provider': [{'_type': 'Organization',
#      'name': 'NPR',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_6c3f7ab5b1adb7289fa57135ed806781&pid=news'}}}],
#    'datePublished': '2020-04-20T20:56:00.0000000Z',
#    'category': 'World',
#    'headline': True},
#   {'name': 'Should Americans Not Have To Pay Rent During The Coronavirus? One Big City May Pass A Law To Help Renters',
#    'url': 'https://www.ibtimes.com/should-americans-not-have-pay-rent-during-coronavirus-one-big-city-may-pass-law-help-2961915',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.731C298A127B7FFA3A501E3E3AE4324A&pid=News',
#      'width': 700,
#      'height': 525}},
#    'description': 'Chicago Alderman Matt Martin said he would introduce an ordinance to give tenants a year to catch up on their rent Martin also called on Illinois Gov J.B. Pritzker to pressure mortgage lenders to offer to suspend or reduce mortgage pauments for three months Two King County, Washington, councilmembers have called for a freeze on rent and ...',
#    'provider': [{'_type': 'Organization',
#      'name': 'International Business Times',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_9f6a911c9d042b01c6b85e9c12aa8647&pid=news'}}}],
#    'datePublished': '2020-04-20T19:57:00.0000000Z',
#    'headline': True,
#    'ampUrl': 'https://www.ibtimes.com/should-americans-not-have-pay-rent-during-coronavirus-one-big-city-may-pass-law-help-2961915?amp=1'},
#   {'name': 'Disney furloughs 100,000 theme park and hotel workers amid coronavirus shutdown',
#    'url': 'https://www.nbcnews.com/news/us-news/disney-furloughs-100-000-theme-park-hotel-workers-amid-coronavirus-n1188236',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.6C6F6B71A0EF46744E0DBE289D173418&pid=News',
#      'width': 700,
#      'height': 367}},
#    'description': 'Mickey, Goofy and Minnie were out of a job Monday as Disney furloughed 100,000 theme park and hotel workers, including cast members who play the beloved Walt Disney characters in Florida and elsewhere, because of the coronavirus crisis. Hardest hit was the Walt Disney World Resort in Orlando, where 70,000 workers will now have to rely on ...',
#    'about': [{'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/f4450a17-34ba-5124-0ea8-52c681bfa13d',
#      'name': 'Walt Disney'}],
#    'provider': [{'_type': 'Organization',
#      'name': 'NBC News',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_e4bde9ad3949725c2f4ad268ff549295&pid=news'}}}],
#    'datePublished': '2020-04-20T21:06:00.0000000Z',
#    'category': 'Business',
#    'headline': True,
#    'ampUrl': 'https://www.nbcnews.com/news/amp/ncna1188236'},
#   {'name': 'Gov. Whitmer creates Michigan Coronavirus Task Force on Racial Disparities',
#    'url': 'https://www.freep.com/story/news/health/2020/04/20/michigan-coronavirus-task-force-racial-disparities/5166777002/',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.7FFA7D70D3DFA30F824A738C7BBAA64C&pid=News',
#      'width': 700,
#      'height': 394}},
#    'description': 'Gov. Whitmer creates Michigan Coronavirus Task Force on Racial Disparities Gov. Gretchen Whitmer announced Monday an executive order to create the Michigan Coronavirus Task Force on Racial Disparities to address inequities in the state. Check out this story on Freep.com: https://www.freep.com/story/news/health/2020/04/20/michigan-coronavirus ...',
#    'about': [{'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/99dfe5a0-3e49-d1a6-e492-b76eea23b1d3',
#      'name': 'Whitmer, West Virginia'},
#     {'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/162411c2-b757-495d-aa81-93942fae2f7e',
#      'name': 'Michigan'},
#     {'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/97248c72-fa1e-87de-2759-e3c2ff316232',
#      'name': 'Task force'}],
#    'mentions': [{'name': 'Whitmer, West Virginia'},
#     {'name': 'Michigan'},
#     {'name': 'Task force'}],
#    'provider': [{'_type': 'Organization',
#      'name': 'Detroit Free Press',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_042b9da277622db2efffd94b434374b3&pid=news'}}}],
#    'datePublished': '2020-04-20T19:51:00.0000000Z',
#    'category': 'Politics',
#    'headline': True,
#    'ampUrl': 'https://amp.freep.com/amp/5166777002'},
#   {'name': 'L.A. COVID-19 antibody study adds further support for a higher-than-suspected infection rate',
#    'url': 'https://techcrunch.com/2020/04/20/l-a-covid-19-antibody-study-adds-further-support-for-a-higher-than-suspected-infection-rate/',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.31049CC93F085AF82353E931D90CFCF8&pid=News',
#      'width': 600,
#      'height': 399}},
#    'description': 'A new study conducted by the University of Southern California along with the LA County Department of Public Health indicates that the presence of antibodies for COVID-19 in between 2.5 and 5.6% of the population of LA County, suggesting that between 221,000 and 442,000 individuals had the infection – up to 55 times more people than have been ...',
#    'about': [{'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/96de694e-8d48-6cb9-79fd-a2a77aacd866',
#      'name': 'Rate'}],
#    'mentions': [{'name': 'Rate'},
#     {'name': 'TechCrunch'},
#     {'name': 'University of Southern California'}],
#    'provider': [{'_type': 'Organization',
#      'name': 'TechCrunch',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_41da8f2e70e1e401f764f7157d16f2fa&pid=news'}}}],
#    'datePublished': '2020-04-20T21:02:00.0000000Z',
#    'category': 'Health',
#    'headline': True,
#    'ampUrl': 'https://techcrunch.com/2020/04/20/l-a-covid-19-antibody-study-adds-further-support-for-a-higher-than-suspected-infection-rate/amp/'},
#   {'name': '24 Hour Fitness Considers Bankruptcy As Gyms Remain Closed During Coronavirus Pandemic',
#    'url': 'https://www.ibtimes.com/24-hour-fitness-considers-bankruptcy-gyms-remain-closed-during-coronavirus-pandemic-2961934',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.72D49E7B7C8124891B8558F1B4CD08C0&pid=News',
#      'width': 594,
#      'height': 431}},
#    'description': 'As fitness centers and gyms remain closed because of the coronavirus, 24 Hour Fitness is reportedly considering filing for bankruptcy. According to sources for CNBC, the gym chain is currently working with Lazard, an investment bank, and Weil, Gotshal & Manges, a law firm, to determine its financial options. "You may also have seen news reports ...',
#    'provider': [{'_type': 'Organization',
#      'name': 'International Business Times',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_9f6a911c9d042b01c6b85e9c12aa8647&pid=news'}}}],
#    'datePublished': '2020-04-20T20:17:00.0000000Z',
#    'category': 'Business',
#    'headline': True,
#    'ampUrl': 'https://www.ibtimes.com/24-hour-fitness-considers-bankruptcy-gyms-remain-closed-during-coronavirus-pandemic-2961934?amp=1'},
#   {'name': '‘Just surreal silence.’ A closer look at the Boston Marathon start and finish lines on what should have been race day',
#    'url': 'https://www.bostonglobe.com/2020/04/20/sports/just-surreal-silence-closer-look-boston-marathon-start-finish-lines-what-should-have-been-race-day/',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.BFA3F5FAA60ADAFB01D50E86F1F7F1D9&pid=News',
#      'width': 506,
#      'height': 337}},
#    'description': 'HOPKINTON — The Boston Marathon start line was eerily empty on Patriots’ Day. Blue cones were placed in nearly every parking spot around Hopkinton’s Echo Lake Park, and several police cruisers patrolled the area in hopes of preventing rogue runners from beginning the 26.2-mile trek from its usual spot. “No Parking on Mon.,” read a ...',
#    'about': [{'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/0469e8cf-16e4-3447-cb61-d3d62a0ac24a',
#      'name': 'Boston Marathon'}],
#    'mentions': [{'name': 'Boston Marathon'},
#     {'name': 'The Boston Globe'},
#     {'name': 'Television'}],
#    'provider': [{'_type': 'Organization',
#      'name': 'The Boston Globe',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_9771321dce841bf5c6ffae48d0f78b90&pid=news'}}}],
#    'datePublished': '2020-04-20T20:34:00.0000000Z',
#    'headline': True,
#    'ampUrl': 'https://www.bostonglobe.com/2020/04/20/sports/just-surreal-silence-closer-look-boston-marathon-start-finish-lines-what-should-have-been-race-day/?outputType=amp'},
#   {'name': 'The First Phase Of Reopening The Country Has Begun — And It’s A Patchwork Of Small Steps',
#    'url': 'https://www.forbes.com/sites/jackbrewster/2020/04/20/the-first-phase-of-reopening-the-country-has-begun---and-its-a-patchwork-of-small-steps/',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.BF2ACD5D2BC8CDE5D097BFC817014005&pid=News',
#      'width': 700,
#      'height': 466}},
#    'description': 'States across the country have begun to take small steps towards normalcy, lifting restrictions on everything from beaches to construction to garden-supply stores, in a sign of the cautious and divergent response governors will be taking to dial back social distancing guidelines. JACKSONVILLE BEACH, FL - APRIL 17: People play a game of Spike ...',
#    'about': [{'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/9fcd2468-1733-b091-77f4-a494fdc84aca',
#      'name': 'Phase'},
#     {'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/41ef16fe-89b5-2f58-cfc9-6486244da6a1',
#      'name': 'First Evil'},
#     {'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/4df86b30-039f-c9ed-cfff-83b4d9ae17da',
#      'name': 'Begun'}],
#    'provider': [{'_type': 'Organization',
#      'name': 'Forbes',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_f798ef715781699feff0f3ea5f101626&pid=news'}}}],
#    'datePublished': '2020-04-20T19:21:00.0000000Z',
#    'headline': True,
#    'ampUrl': 'https://www.forbes.com/sites/jackbrewster/2020/04/20/the-first-phase-of-reopening-the-country-has-begun---and-its-a-patchwork-of-small-steps/amp/'},
#   {'name': 'Watch: Trump And Governors Clash On Coronavirus Testing Capacity',
#    'url': 'https://www.npr.org/2020/04/20/837548270/watch-trump-and-governors-clash-on-coronavirus-testing-capacity',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.81910B65936B1B82D573D5867D241E39&pid=News',
#      'width': 700,
#      'height': 393}},
#    'description': "President Trump will address the nation on the coronavirus pandemic on Monday, as state leaders and health experts say that testing limitations continue to slow the country's ability to safely re-open the economy. The White House last week issued guidelines on a three-tiered approach for states to begin easing coronavirus restrictions.",
#    'about': [{'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/541cd519-750b-9c92-8413-a537def6abbe',
#      'name': 'White House'},
#     {'readLink': 'https://api.cognitive.microsoft.com/api/v7/entities/af660955-a30a-65d7-4c4e-89b41945bb5d',
#      'name': 'NPR'}],
#    'provider': [{'_type': 'Organization',
#      'name': 'NPR',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_6c3f7ab5b1adb7289fa57135ed806781&pid=news'}}}],
#    'datePublished': '2020-04-20T20:30:00.0000000Z',
#    'headline': True},
#   {'name': 'U.S. Oil Prices Plunge Into Negative Territory: Live Markets Updates',
#    'url': 'https://www.nytimes.com/2020/04/20/business/stock-market-live-trading-coronavirus.html',
#    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ON.1C6C00D3D424921AE8AB6E2FD5058DBE&pid=News',
#      'width': 700,
#      'height': 366}},
#    'description': 'Something bizarre happened in the markets: The price of a barrel of oil went negative. Oil plummets as storage capacity runs low, and a quirk in pricing wipes out one benchmark. Small-business owners say big banks ignored them in favor of wealthy clients. Shake Shack says it will return its $10 million loan, while the restaurant industry asks ...',
#    'provider': [{'_type': 'Organization',
#      'name': 'New York Times',
#      'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=AR_cc657c1af702fae867766bbf2aa25756&pid=news'}}}],
#    'datePublished': '2020-04-20T19:09:00.0000000Z',
#    'category': 'Business',
#    'headline': True,
#    'ampUrl': 'https://www.nytimes.com/2020/04/20/business/stock-market-live-trading-coronavirus.amp.html'}]}

# %%
def get_sentiment(text):
    url = "http://text-processing.com/api/sentiment/"
    body = f"text='{text}'"
    response = requests.post(url, data=body)
    return response.json()

get_sentiment("I do not like you at all you smell bad")
# Out:
# {'probability': {'neg': 0.7490215341307409,
#   'neutral': 0.33450803359775344,
#   'pos': 0.2509784658692591},
#  'label': 'neg'}
